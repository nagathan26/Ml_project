# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import json
import os
import time

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

# %%
df = pd.read_csv('Crop_recommendation.csv')

print(df.shape)
df.head()
# Out:
# (2200, 8)
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
print(df.isnull().sum())
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

fig,axes = plt.subplots(2,4,figsize = (18,8))
axes = axes.flatten()

for i,col in enumerate(features):
    axes[i].hist(df[col],bins= 30,color = 'green',alpha = 0.7,edgecolor='black')
    axes[i].set_title(f'{col} distribution')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')


axes[-1].axis('off')
plt.suptitle('Feature Distributions', fontsize=16)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.heatmap(df[features].corr(),annot = True,fmt=".2f",cmap="YlGn",linewidths=0.5)
plt.title("feature correlation heatmap")
plt.show()

# %%
plt.figure(figsize = (20,6))
sns.boxenplot(data=df,x="label",y="N",palette='Set2')
plt.xticks(rotation=45)
plt.title("Nitrogen(N) levels per Crop")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sanke\AppData\Local\Temp\ipykernel_4472\210557475.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(data=df,x="label",y="N",palette='Set2')

# %%
x = df[features].values
y = df['label'].values

le = LabelEncoder()
y_enc = le.fit_transform(y)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

X_train, X_test, Y_train, Y_test = train_test_split(
    X_scaled, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

print(list(le.classes_))
print(X_train.shape)
print(X_test.shape)
# Out:
# ['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee', 'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize', 'mango', 'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya', 'pigeonpeas', 'pomegranate', 'rice', 'watermelon']
# (1760, 7)
# (440, 7)

# %%
n_classes = len(le.classes_)

MODELS = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),

    "Naive Bayes": GaussianNB(),

    "Decision Tree": DecisionTreeClassifier(random_state=42),

    "XGBoost": XGBClassifier(
    n_estimators=100,
    objective="multi:softmax",
    num_class=n_classes,
    eval_metric="mlogloss",
    use_label_encoder=False,
    random_state=42
    )
}

print(f"{len(MODELS)} models defined")
# Out:
# 4 models defined

# %%
metrics = {}
for name, model in MODELS.items():
    print(f"training:{name}...", end=" ")

    t0 = time.time()
    model.fit(X_train, Y_train)
    elapsed = round(time.time() - t0, 3)

    y_pred = model.predict(X_test)

    acc = round(accuracy_score(y_test, y_pred) * 100, 2)
    prec = round(precision_score(y_test, y_pred, average="weighted") * 100, 2)
    rec = round(recall_score(y_test, y_pred, average="weighted") * 100, 2)
    f1 = round(f1_score(y_test, y_pred, average="weighted") * 100, 2)

    slug = name.lower().replace(" ", "_").replace("-", "_")

    metrics[name] = {
        "accuracy": acc,
        "precision": prec,
        "recall": rec,
        "f1": f1,
        "train_time": elapsed,
        "slug": slug,
    }

    print(f"Accuracy={acc}%  F1={f1}%  Time={elapsed}s")
# Out:
# training:Logistic Regression... Accuracy=97.27%  F1=97.25%  Time=0.127s
# training:Naive Bayes... Accuracy=99.55%  F1=99.54%  Time=0.003s
# training:Decision Tree... Accuracy=97.95%  F1=97.94%  Time=0.027s
# training:XGBoost...
# C:\Users\sanke\AppData\Roaming\Python\Python313\site-packages\xgboost\training.py:183: UserWarning: [15:28:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy=99.32%  F1=99.31%  Time=1.533s
